# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %% [markdown]
# # Reading the data

# %%
file_path_screwdriver = r"C:\Users\Daniel\OneDrive\Bachelorarbeit\Daten\Datenaufnahme\Schraubendreher\1\2021-02-08Griff_Schraubendreher_ml EULERWINKEL.json"
file_path_fist = r"C:\Users\Daniel\OneDrive\Bachelorarbeit\Daten\Datenaufnahme\Faust\1\2021-02-08Faust_ml EULERWINKEL.json"
file_path_list = [file_path_screwdriver,file_path_fist]
description_list = ["screwdriver","fist"]
df_list = []
for element in file_path_list:
    df_list.append(pd.read_json(element))

# %% [markdown]
# # Preprocessing

# %%
def func_df_preparation(df):
    df.drop(["userName","typeOfRecording","nameOfTask"],axis=1,inplace=True)
    df.sort_values(["timeStamp"],ignore_index=True,inplace=True)
    df.drop_duplicates(subset=["timeStamp"],keep="first",inplace=True,ignore_index=True)
    return df

# %%
for ind,element in enumerate(df_list):
    df_list[ind] = func_df_preparation(element)
    print("Number unique testing sequences {}:\t {}".format(description_list[ind],element["recordingNumber"].nunique()))
# Out:
# Number unique testing sequences screwdriver:	 9
# Number unique testing sequences fist:	 10

# %% [markdown]
# ## Rearranging the data + combine the datasets
#
# columns = 6 parameters (3x acc and 3x angle) for each sensor
#    rows = each row represents one moment
#
# all unique testing sequences are combined
#
# last column ["label"]:
#
#     1 = screwdriver
#     2 = fist

# %%
column_names_list = df_list[0].columns.tolist()
column_names_list.remove("timeStamp")
column_names_list.remove("frameNumber")
column_names_list.remove("recordingNumber")
column_names_list
# Out:
# ['phi', 'theta', 'psi', 'accX', 'accY', 'accZ']

# %%
def func_all_sensors_list(df):
    n_sensors = len(df["psi"].iloc[0])
    all_sensors_list_df = []
    temp_df = df.copy()
    for sensor_index in range(n_sensors):
        for index, row in df.iterrows():
            for c_name in column_names_list:
                temp_df[c_name].iloc[index] = row[c_name][sensor_index]
        temp_df[column_names_list] = temp_df[column_names_list].astype(float)
        all_sensors_list_df.append(temp_df.copy())
    return all_sensors_list_df

# %%
all_sensors_list = []
for element in df_list:
    all_sensors_list.append(func_all_sensors_list(element))
# Out:
# C:\Users\Daniel\anaconda3\envs\gputest\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
def func_index_recNum_list(df):
    index_recNum_list_df = []
    for recording in range(1,df["recordingNumber"].nunique()+1):
        index_recNum_list_df.append(df[df["recordingNumber"]==recording].first_valid_index())
    index_recNum_list_df.append(df.last_valid_index()+1)
    return index_recNum_list_df

# %%
index_recNum_list = []
for element in df_list:
    index_recNum_list.append(func_index_recNum_list(element))

# %%
def func_delta_time(df,index_recNum_list_df):
    delta_time = []
    for ind in range(1,len(index_recNum_list_df)):
        t1 = df["timeStamp"].iloc[index_recNum_list_df[ind-1]]
        t2 = df["timeStamp"].iloc[index_recNum_list_df[ind]-1]
        delta_time.append((t2-t1))
    arr = np.array(delta_time)
    print(arr.mean())

# %%
for ind,element in enumerate(df_list):
    func_delta_time(element,index_recNum_list[ind])
# Out:
# 0 days 00:00:07.877888970
# 0 days 00:00:08.122999930

# %%
def func_df_data(df,all_sensors_list_df,label):
    data_df = df.copy()
    data_df = data_df[["recordingNumber","timeStamp","frameNumber"]]
    for ind_sensor in range(14):
        for ind_feat in range(6):
            col_name = column_names_list[ind_feat]+str(ind_sensor)
            data_df[col_name] = all_sensors_list_df[ind_sensor][column_names_list[ind_feat]]
    data_df["label"] = label
    return(data_df)

# %%
all_sensors_list[0][0].head()
# Out:
#         phi     theta       psi      accX      accY      accZ  \
# 0 -3.099992 -0.251864  0.986599  0.052692 -0.037947  0.057099
# 1 -3.099264 -0.251283  0.986628  0.023943 -0.007743  0.020854
# 2 -3.098992 -0.251014  0.986708  0.044817  0.023827  0.030549
# 3 -3.098992 -0.251014  0.986708  0.044817  0.023827  0.030549
# 4 -3.098435 -0.250482  0.986756  0.024754 -0.005931  0.013268
#
#                       timeStamp  frameNumber  recordingNumber
# 0 2021-02-08 10:26:04.840999842        43291                1
# 1 2021-02-08 10:26:04.874000072        43292                1
# 2 2021-02-08 10:26:04.907000065        43293                1
# 3 2021-02-08 10:26:04.940999985        43294                1
# 4 2021-02-08 10:26:04.973999977        43295                1

# %%
index_recNum_list[1]
# Out:
# [0, 172, 378, 618, 873, 1107, 1317, 1593, 1879, 2167, 2447]

# %%
df_data_list = []
for ind,element in enumerate(df_list):
    df_data_list.append(func_df_data(element,all_sensors_list[ind],ind))
df_data_list[0].head()
# Out:
#    recordingNumber                     timeStamp  frameNumber      phi0  \
# 0                1 2021-02-08 10:26:04.840999842        43291 -3.099992
# 1                1 2021-02-08 10:26:04.874000072        43292 -3.099264
# 2                1 2021-02-08 10:26:04.907000065        43293 -3.098992
# 3                1 2021-02-08 10:26:04.940999985        43294 -3.098992
# 4                1 2021-02-08 10:26:04.973999977        43295 -3.098435
#
#      theta0      psi0     accX0     accY0     accZ0      phi1  ...    accX12  \
# 0 -0.251864  0.986599  0.052692 -0.037947  0.057099 -0.341761  ... -0.192187
# 1 -0.251283  0.986628  0.023943 -0.007743  0.020854 -0.342838  ... -0.080367
# 2 -0.251014  0.986708  0.044817  0.023827  0.030549 -0.343988  ...  0.079542
# 3 -0.251014  0.986708  0.044817  0.023827  0.030549 -0.345417  ... -0.051852
# 4 -0.250482  0.986756  0.024754 -0.005931  0.013268 -0.345417  ... -0.040753
#
#      accY12    accZ12     phi13   theta13     psi13    accX13    accY13  \
# 0 -0.057048  0.335394  0.225838 -0.292762  0.669282 -0.224155 -0.062544
# 1 -0.088077 -0.171578  0.224768 -0.294493  0.670230 -0.040612  0.017532
# 2  0.002126 -0.097973  0.224612 -0.294871  0.670486  0.106944 -0.051276
# 3  0.027972 -0.113384  0.225321 -0.297056  0.671869 -0.024738 -0.025348
# 4 -0.019390  0.002805  0.226185 -0.297756  0.672643 -0.165805 -0.128674
#
#      accZ13  label
# 0  0.400648      0
# 1 -0.294340      0
# 2 -0.009687      0
# 3 -0.045350      0
# 4 -0.021833      0
#
# [5 rows x 88 columns]

# %%
result = pd.concat(df_data_list,ignore_index=True)
result.shape
# Out:
# (4583, 88)

# %%
for ind in range(1,len(index_recNum_list)):
    index_recNum_list[ind] = [x+index_recNum_list[ind-1][-1] for x in index_recNum_list[ind]]
index_recNum_list[1]
# Out:
# [2136, 2308, 2514, 2754, 3009, 3243, 3453, 3729, 4015, 4303, 4583]

# %%
result.sample(10)
# Out:
#       recordingNumber                     timeStamp  frameNumber      phi0  \
# 2424                2 2021-02-08 10:31:55.842000008        53821 -3.100170
# 4150                9 2021-02-08 10:33:37.143000126        56860 -3.099828
# 4189                9 2021-02-08 10:33:38.443000078        56899 -3.099828
# 3723                7 2021-02-08 10:33:09.875999928        56042 -3.101188
# 2017                9 2021-02-08 10:28:03.974999905        46865 -3.097827
# 4336               10 2021-02-08 10:33:50.042999983        57247 -3.100055
# 1761                8 2021-02-08 10:27:49.874000072        46442 -3.098015
# 903                 4 2021-02-08 10:26:56.873999834        44852 -3.094464
# 2654                3 2021-02-08 10:32:08.842000008        54211 -3.099618
# 4201                9 2021-02-08 10:33:38.844000101        56911 -3.099828
#
#         theta0      psi0     accX0     accY0     accZ0      phi1  ...  \
# 2424 -0.261886  1.003980 -0.000449 -0.039158  0.018528 -0.341875  ...
# 4150 -0.261349  0.997714  0.007344  0.021886 -0.038288 -0.372454  ...
# 4189 -0.261349  0.997714  0.013943  0.014708  0.001119 -0.372454  ...
# 3723 -0.263633  0.998682 -0.020056 -0.024228 -0.004223 -0.367063  ...
# 2017 -0.244636  0.983102  0.001482  0.015993  0.007902 -0.378626  ...
# 4336 -0.260527  0.996268 -0.004119 -0.001270  0.027561 -0.366326  ...
# 1761 -0.241608  0.983016  0.006839  0.012412 -0.024655 -0.377448  ...
# 903  -0.245994  0.982773  0.030986 -0.023531 -0.006521 -0.373449  ...
# 2654 -0.262175  1.003901  0.004788  0.016314 -0.015652 -0.349760  ...
# 4201 -0.261349  0.997714  0.009850  0.008367 -0.000900 -0.372454  ...
#
#         accX12    accY12    accZ12     phi13   theta13     psi13    accX13  \
# 2424  0.146335  0.035267 -0.057158  1.798290 -0.205046  1.296788 -0.141447
# 4150  0.053613 -0.023322  0.188311  2.073994 -0.175896  1.201821  0.005916
# 4189  0.096544  0.021119  0.272121  2.053861 -0.170895  1.226201  0.046352
# 3723 -0.019726  0.105770 -0.203025  0.221373 -0.239263  0.964037  0.086673
# 2017  0.059852  0.068861  0.129760  1.043390 -0.265249  0.672205  0.040732
# 4336 -0.004968 -0.089485  0.069394  0.178919 -0.232130  0.949645 -0.042936
# 1761  0.562810  0.948505 -0.475616  0.639445 -0.239223  0.594165  0.853586
# 903   0.175212  0.018525  0.204570  0.145906 -0.224339  0.513166 -0.435836
# 2654 -0.054090  0.001441 -0.209162  2.070259 -0.229690  1.381381 -0.017508
# 4201 -1.442270  1.312006 -2.151243  0.391658 -0.231971  1.010347 -0.719781
#
#         accY13    accZ13  label
# 2424  0.021030  0.201799      1
# 4150 -0.018131  0.217075      1
# 4189 -0.019188  0.335485      1
# 3723  0.205942 -0.286282      1
# 2017  0.090539  0.137056      0
# 4336 -0.036387  0.112022      1
# 1761  1.086951 -0.432740      0
# 903  -0.089084 -0.497233      0
# 2654  0.001578 -0.301358      1
# 4201  0.804069 -0.974568      1
#
# [10 rows x 88 columns]

# %%
start_ind_right_hand = 3+6*7
pure_data = result[result.columns[start_ind_right_hand:]]
pure_data
# Out:
#           phi7    theta7      psi7     accX7     accY7     accZ7      phi8  \
# 0     0.080651  0.148847 -0.959140 -0.049675  0.134449  0.103026 -0.283347
# 1     0.080651  0.148847 -0.959140 -0.049675  0.134449  0.103026 -0.286494
# 2     0.083520  0.145020 -0.958043  0.155792 -0.073801 -0.054326 -0.288562
# 3     0.084042  0.144297 -0.957704  0.083194 -0.060714 -0.035120 -0.289412
# 4     0.084970  0.142817 -0.957260  0.080727 -0.063714 -0.082944 -0.291794
# ...        ...       ...       ...       ...       ...       ...       ...
# 4578 -0.000788  0.131263 -0.888502 -0.076930 -0.029085  0.101990 -0.383999
# 4579  0.000603  0.129653 -0.889342 -0.013478  0.004246 -0.029982 -0.383999
# 4580  0.001227  0.128868 -0.889633  0.012872 -0.102590 -0.082346 -0.383633
# 4581  0.001227  0.128868 -0.889633  0.012872 -0.102590 -0.082346 -0.383148
# 4582  0.001784  0.128204 -0.890144  0.050478 -0.018799 -0.037438 -0.383148
#
#         theta8      psi8     accX8  ...    accX12    accY12    accZ12  \
# 0    -0.518190 -0.919459 -0.056956  ... -0.192187 -0.057048  0.335394
# 1    -0.523345 -0.917932 -0.138175  ... -0.080367 -0.088077 -0.171578
# 2    -0.524751 -0.916598 -0.120184  ...  0.079542  0.002126 -0.097973
# 3    -0.525137 -0.915855 -0.085881  ... -0.051852  0.027972 -0.113384
# 4    -0.527175 -0.915196 -0.099641  ... -0.040753 -0.019390  0.002805
# ...        ...       ...       ...  ...       ...       ...       ...
# 4578 -0.487630 -0.916883 -0.021625  ... -0.093461 -0.024301  0.113809
# 4579 -0.487630 -0.916883 -0.021625  ... -0.032861 -0.036520 -0.231586
# 4580 -0.488823 -0.918637 -0.029767  ...  0.083403 -0.104163  0.091948
# 4581 -0.490075 -0.920805  0.028057  ... -0.002063 -0.048087 -0.077849
# 4582 -0.490075 -0.920805  0.028057  ... -0.009213  0.078099  0.065679
#
#          phi13   theta13     psi13    accX13    accY13    accZ13  label
# 0     0.225838 -0.292762  0.669282 -0.224155 -0.062544  0.400648      0
# 1     0.224768 -0.294493  0.670230 -0.040612  0.017532 -0.294340      0
# 2     0.224612 -0.294871  0.670486  0.106944 -0.051276 -0.009687      0
# 3     0.225321 -0.297056  0.671869 -0.024738 -0.025348 -0.045350      0
# 4     0.226185 -0.297756  0.672643 -0.165805 -0.128674 -0.021833      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 4578  0.188865 -0.240217  0.950502 -0.041030 -0.013941  0.176515      1
# 4579  0.188396 -0.240344  0.948447 -0.009833  0.002942 -0.117649      1
# 4580  0.187876 -0.240420  0.947173  0.068939 -0.039344 -0.001130      1
# 4581  0.187152 -0.240386  0.945828 -0.051900 -0.089484 -0.055887      1
# 4582  0.186488 -0.240263  0.944539  0.051060  0.112721  0.046783      1
#
# [4583 rows x 43 columns]

# %%
X_test_noMovement = result.loc[index_recNum_list[0][0]:index_recNum_list[0][1]].values
X_test_noMovement = X_test_noMovement[:,3:(3+6*7)]
X_test_noMovement.shape
# Out:
# (254, 42)

# %% [markdown]
# # Classification

# %%
models = []
models.append(("LR",LogisticRegression()))
models.append(("LDA",LinearDiscriminantAnalysis()))
models.append(("KNN",KNeighborsClassifier()))
models.append(("CART",DecisionTreeClassifier()))
models.append(("NB",GaussianNB()))
models.append(("SVM",SVC()))

# %%
# shuffle
cols = list(pure_data.columns[:-1])
X = pure_data[cols].values
Y = pure_data["label"].values
X_train_shuffle,X_test_shuffle,Y_train_shuffle,Y_test_shuffle = model_selection.train_test_split(
    X,Y,test_size=0.8,shuffle=True,random_state=42)

# %%
results = []
names = []
for name, model in models:
    print(name+"\n")
    model.fit(X_train_shuffle,Y_train_shuffle)
    prediction = model.predict(X_test_shuffle)
    print(accuracy_score(Y_test_shuffle,prediction))
    print(confusion_matrix(Y_test_shuffle,prediction))
    print(classification_report(Y_test_shuffle,prediction))
    print("\n")
    print("\n")
    print("\n")
# Out:
# LR
#
# 0.9991818925552223
# [[1708    0]
#  [   3 1956]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1708
#            1       1.00      1.00      1.00      1959
#
#     accuracy                           1.00      3667
#    macro avg       1.00      1.00      1.00      3667
# weighted avg       1.00      1.00      1.00      3667
#
#
#
#
#
#
#
# LDA
#
# 1.0
# [[1708    0]
#  [   0 1959]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1708
#            1       1.00      1.00      1.00      1959
#
#     accuracy                           1.00      3667
#    macro avg       1.00      1.00      1.00      3667
# weighted avg       1.00      1.00      1.00      3667
#
#
#
#
#
#
#
# KNN
#
# 0.9893646032178893
# [[1691   17]
#  [  22 1937]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1708
#            1       0.99      0.99      0.99      1959
#
#     accuracy                           0.99      3667
#    macro avg       0.99      0.99      0.99      3667
# weighted avg       0.99      0.99      0.99      3667
#
#
#
#
#
#
#
# CART
#
# 1.0
# [[1708    0]
#  [   0 1959]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1708
#            1       1.00      1.00      1.00      1959
#
#     accuracy                           1.00      3667
#    macro avg       1.00      1.00      1.00      3667
# weighted avg       1.00      1.00      1.00      3667
#
#
#
#
#
#
#
# NB
#
# 0.9907281156258522
# [[1674   34]
#  [   0 1959]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      1708
#            1       0.98      1.00      0.99      1959
#
#     accuracy                           0.99      3667
#    macro avg       0.99      0.99      0.99      3667
# weighted avg       0.99      0.99      0.99      3667
#
#
#
#
#
#
#
# SVM
#
# 0.996727570220889
# [[1696   12]
#  [   0 1959]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      1708
#            1       0.99      1.00      1.00      1959
#
#     accuracy                           1.00      3667
#    macro avg       1.00      1.00      1.00      3667
# weighted avg       1.00      1.00      1.00      3667

# %%
# testing input shape
pure_data.shape[0]-(X_train_shuffle.shape[0]+X_test_shuffle.shape[0])
# Out:
# 0

# %% [markdown]
# ## accuracy is pretty good -> only the acc values are used

# %%
cols_acc = []
for col in pure_data.columns:
    if "phi" not in col and "theta" not in col and "psi" not in col and "label" not in col:
        cols_acc.append(col)

# %%
X = pure_data[cols_acc]
X_train_shuffle,X_test_shuffle,Y_train_shuffle,Y_test_shuffle = model_selection.train_test_split(
    X,Y,test_size=0.8,shuffle=True,random_state=42)

# %%
results = []
names = []
for name, model in models:
    print(name+"\n")
    model.fit(X_train_shuffle,Y_train_shuffle)
    prediction = model.predict(X_test_shuffle)
    print(accuracy_score(Y_test_shuffle,prediction))
    print(confusion_matrix(Y_test_shuffle,prediction))
    print(classification_report(Y_test_shuffle,prediction))
    print("\n")
    print("\n")
    print("\n")
# Out:
# LR
#
# 0.5418598309244614
# [[ 314 1394]
#  [ 286 1673]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.18      0.27      1708
#            1       0.55      0.85      0.67      1959
#
#     accuracy                           0.54      3667
#    macro avg       0.53      0.52      0.47      3667
# weighted avg       0.54      0.54      0.48      3667
#
#
#
#
#
#
#
# LDA
#
# 0.5434960458140169
# [[ 374 1334]
#  [ 340 1619]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.22      0.31      1708
#            1       0.55      0.83      0.66      1959
#
#     accuracy                           0.54      3667
#    macro avg       0.54      0.52      0.48      3667
# weighted avg       0.54      0.54      0.50      3667
#
#
#
#
#
#
#
# KNN
#
# 0.7281156258521952
# [[1206  502]
#  [ 495 1464]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71      1708
#            1       0.74      0.75      0.75      1959
#
#     accuracy                           0.73      3667
#    macro avg       0.73      0.73      0.73      3667
# weighted avg       0.73      0.73      0.73      3667
#
#
#
#
#
#
#
# CART
#
# 0.685846741205345
# [[1149  559]
#  [ 593 1366]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.67      0.67      1708
#            1       0.71      0.70      0.70      1959
#
#     accuracy                           0.69      3667
#    macro avg       0.68      0.69      0.68      3667
# weighted avg       0.69      0.69      0.69      3667
#
#
#
#
#
#
#
# NB
#
# 0.5118625579492774
# [[1502  206]
#  [1584  375]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.88      0.63      1708
#            1       0.65      0.19      0.30      1959
#
#     accuracy                           0.51      3667
#    macro avg       0.57      0.54      0.46      3667
# weighted avg       0.57      0.51      0.45      3667
#
#
#
#
#
#
#
# SVM
#
# 0.6855740387237523
# [[1290  418]
#  [ 735 1224]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.76      0.69      1708
#            1       0.75      0.62      0.68      1959
#
#     accuracy                           0.69      3667
#    macro avg       0.69      0.69      0.69      3667
# weighted avg       0.69      0.69      0.69      3667

# %%
models
# Out:
# [('LR', LogisticRegression()),
#  ('LDA', LinearDiscriminantAnalysis()),
#  ('KNN', KNeighborsClassifier()),
#  ('CART', DecisionTreeClassifier()),
#  ('NB', GaussianNB()),
#  ('SVM', SVC())]

# %%
from sklearn_porter import Porter
# Out:
# C:\Users\Daniel\anaconda3\envs\gputest\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.tree.tree module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.tree. Anything that cannot be imported from sklearn.tree is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\Daniel\anaconda3\envs\gputest\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.ensemble.weight_boosting module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\Daniel\anaconda3\envs\gputest\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\Daniel\anaconda3\envs\gputest\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.svm.classes module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.svm. Anything that cannot be imported from sklearn.svm is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\Daniel\anaconda3\envs\gputest\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.neighbors.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train_shuffle,Y_train_shuffle)
# Out:
# DecisionTreeClassifier()

# %%
porter = Porter(clf, language='java')
output = porter.export(embed_data=True)
print(output)
# Out:
# class DecisionTreeClassifier {
#
#     private static int findMax(int[] nums) {
#         int index = 0;
#         for (int i = 0; i < nums.length; i++) {
#             index = nums[i] > nums[index] ? i : index;
#         }
#         return index;
#     }
#
#     public static int predict(double[] features) {
#         int[] classes = new int[2];
#
#         if (features[7] <= -0.05785500071942806) {
#             if (features[12] <= 0.053450001403689384) {
#                 if (features[9] <= -0.0041810000548139215) {
#                     if (features[6] <= -0.18997200578451157) {
#                         if (features[20] <= -0.6787029802799225) {
#                             classes[0] = 0;
#                             classes[1] = 1;
#                         } else {
#                             classes[0] = 5;
#                             classes[1] = 0;
#                         }
#                     } else {
#                         if (features[7] <= -0.14100050181150436) {
#                             if (features[8] <= -1.1012035012245178) {
#                                 if (features[18] <= -0.47411451395601034) {
#                                     classes[0] = 0;
#                                     classes[1] = 2;
#                                 } else {
#                                     classes[0] = 3;
#                                     classes[1] = 0;
#                                 }
#                             } else {
#                                 if (features[15] <= 0.5646445006132126) {
#                                     if (features[20] <= -2.21019446849823) {
#                                         if (features[20] <= -3.0548640489578247) {
#                                             classes[0] = 0;
#                                             classes[1] = 2;
#                                         } else {
#                                             classes[0] = 1;
#                                             classes[1] = 0;
#                                         }
#                                     } else {
#                                         if (features[17] <= 0.3920300006866455) {
#                                             classes[0] = 0;
#                                             classes[1] = 72;
#                                         } else {
#                                             if (features[17] <= 0.41148850321769714) {
#                                                 classes[0] = 1;
#                                                 classes[1] = 0;
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 10;
#                                             }
#                                         }
#                                     }
#                                 } else {
#                                     classes[0] = 1;
#                                     classes[1] = 0;
#                                 }
#                             }
#                         } else {
#                             if (features[3] <= -0.018912499770522118) {
#                                 if (features[17] <= -0.14663800597190857) {
#                                     if (features[17] <= -0.24552950263023376) {
#                                         classes[0] = 0;
#                                         classes[1] = 2;
#                                     } else {
#                                         classes[0] = 2;
#                                         classes[1] = 0;
#                                     }
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 25;
#                                 }
#                             } else {
#                                 if (features[7] <= -0.09271200001239777) {
#                                     if (features[3] <= -0.007622499950230122) {
#                                         classes[0] = 0;
#                                         classes[1] = 2;
#                                     } else {
#                                         if (features[19] <= -0.01065900013782084) {
#                                             classes[0] = 6;
#                                             classes[1] = 0;
#                                         } else {
#                                             if (features[10] <= 0.04962850175797939) {
#                                                 classes[0] = 0;
#                                                 classes[1] = 2;
#                                             } else {
#                                                 classes[0] = 2;
#                                                 classes[1] = 0;
#                                             }
#                                         }
#                                     }
#                                 } else {
#                                     if (features[3] <= -0.011316000251099467) {
#                                         classes[0] = 3;
#                                         classes[1] = 0;
#                                     } else {
#                                         if (features[4] <= -0.11652400344610214) {
#                                             classes[0] = 2;
#                                             classes[1] = 0;
#                                         } else {
#                                             if (features[1] <= -0.11567499861121178) {
#                                                 classes[0] = 1;
#                                                 classes[1] = 0;
#                                             } else {
#                                                 if (features[4] <= 0.057273998856544495) {
#                                                     classes[0] = 0;
#                                                     classes[1] = 19;
#                                                 } else {
#                                                     classes[0] = 1;
#                                                     classes[1] = 0;
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#                     }
#                 } else {
#                     if (features[3] <= -0.03721449989825487) {
#                         if (features[16] <= -0.1339619979262352) {
#                             if (features[19] <= 0.11125049367547035) {
#                                 classes[0] = 1;
#                                 classes[1] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 1;
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 9;
#                         }
#                     } else {
#                         if (features[20] <= -0.012110999785363674) {
#                             if (features[15] <= -0.04412749968469143) {
#                                 if (features[19] <= 0.3063590005040169) {
#                                     classes[0] = 5;
#                                     classes[1] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 2;
#                                 }
#                             } else {
#                                 if (features[6] <= 0.27561650425195694) {
#                                     classes[0] = 0;
#                                     classes[1] = 10;
#                                 } else {
#                                     classes[0] = 1;
#                                     classes[1] = 0;
#                                 }
#                             }
#                         } else {
#                             if (features[15] <= -0.4623575061559677) {
#                                 classes[0] = 0;
#                                 classes[1] = 1;
#                             } else {
#                                 if (features[12] <= 0.04264099895954132) {
#                                     classes[0] = 18;
#                                     classes[1] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 1;
#                                 }
#                             }
#                         }
#                     }
#                 }
#             } else {
#                 if (features[10] <= -0.2700200080871582) {
#                     if (features[15] <= 0.04669700004160404) {
#                         classes[0] = 4;
#                         classes[1] = 0;
#                     } else {
#                         if (features[14] <= -1.9438725113868713) {
#                             classes[0] = 1;
#                             classes[1] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 19;
#                         }
#                     }
#                 } else {
#                     if (features[14] <= 1.358308494091034) {
#                         if (features[3] <= 0.06765349954366684) {
#                             classes[0] = 26;
#                             classes[1] = 0;
#                         } else {
#                             if (features[6] <= 0.09902900084853172) {
#                                 classes[0] = 0;
#                                 classes[1] = 3;
#                             } else {
#                                 if (features[11] <= -0.13838349841535091) {
#                                     if (features[11] <= -0.3190179914236069) {
#                                         if (features[7] <= -0.9349825382232666) {
#                                             classes[0] = 0;
#                                             classes[1] = 1;
#                                         } else {
#                                             classes[0] = 3;
#                                             classes[1] = 0;
#                                         }
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 2;
#                                     }
#                                 } else {
#                                     classes[0] = 12;
#                                     classes[1] = 0;
#                                 }
#                             }
#                         }
#                     } else {
#                         classes[0] = 0;
#                         classes[1] = 2;
#                     }
#                 }
#             }
#         } else {
#             if (features[9] <= 0.10284750163555145) {
#                 if (features[10] <= 0.3815775066614151) {
#                     if (features[4] <= -0.06702899932861328) {
#                         if (features[10] <= 0.15240749716758728) {
#                             if (features[16] <= -0.12849899381399155) {
#                                 if (features[15] <= -0.056882500648498535) {
#                                     if (features[5] <= -0.4480244964361191) {
#                                         classes[0] = 0;
#                                         classes[1] = 1;
#                                     } else {
#                                         classes[0] = 9;
#                                         classes[1] = 0;
#                                     }
#                                 } else {
#                                     if (features[8] <= 1.3193034455180168) {
#                                         classes[0] = 0;
#                                         classes[1] = 5;
#                                     } else {
#                                         classes[0] = 1;
#                                         classes[1] = 0;
#                                     }
#                                 }
#                             } else {
#                                 if (features[8] <= -0.19092249870300293) {
#                                     if (features[6] <= 0.0035899998620152473) {
#                                         classes[0] = 3;
#                                         classes[1] = 0;
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 1;
#                                     }
#                                 } else {
#                                     classes[0] = 35;
#                                     classes[1] = 0;
#                                 }
#                             }
#                         } else {
#                             if (features[1] <= -0.09622350335121155) {
#                                 classes[0] = 1;
#                                 classes[1] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 3;
#                             }
#                         }
#                     } else {
#                         if (features[15] <= 0.017121000215411186) {
#                             if (features[13] <= -0.06268350221216679) {
#                                 if (features[12] <= -0.45895548164844513) {
#                                     classes[0] = 0;
#                                     classes[1] = 5;
#                                 } else {
#                                     if (features[15] <= -0.03914649970829487) {
#                                         if (features[11] <= 0.16605249792337418) {
#                                             classes[0] = 28;
#                                             classes[1] = 0;
#                                         } else {
#                                             if (features[5] <= 0.08093399927020073) {
#                                                 classes[0] = 0;
#                                                 classes[1] = 2;
#                                             } else {
#                                                 classes[0] = 4;
#                                                 classes[1] = 0;
#                                             }
#                                         }
#                                     } else {
#                                         if (features[14] <= -0.10356099903583527) {
#                                             classes[0] = 0;
#                                             classes[1] = 3;
#                                         } else {
#                                             if (features[11] <= 0.09825850278139114) {
#                                                 classes[0] = 9;
#                                                 classes[1] = 0;
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 3;
#                                             }
#                                         }
#                                     }
#                                 }
#                             } else {
#                                 if (features[10] <= 0.16564449667930603) {
#                                     if (features[11] <= -0.054992999881505966) {
#                                         if (features[12] <= 0.035969000309705734) {
#                                             if (features[2] <= 0.03010750003159046) {
#                                                 if (features[1] <= -0.11072500050067902) {
#                                                     classes[0] = 2;
#                                                     classes[1] = 0;
#                                                 } else {
#                                                     if (features[18] <= -0.2645709961652756) {
#                                                         classes[0] = 2;
#                                                         classes[1] = 0;
#                                                     } else {
#                                                         if (features[19] <= 0.14406149834394455) {
#                                                             if (features[1] <= -0.07178949937224388) {
#                                                                 if (features[10] <= 0.04476800002157688) {
#                                                                     classes[0] = 0;
#                                                                     classes[1] = 2;
#                                                                 } else {
#                                                                     classes[0] = 1;
#                                                                     classes[1] = 0;
#                                                                 }
#                                                             } else {
#                                                                 classes[0] = 0;
#                                                                 classes[1] = 41;
#                                                             }
#                                                         } else {
#                                                             classes[0] = 1;
#                                                             classes[1] = 0;
#                                                         }
#                                                     }
#                                                 }
#                                             } else {
#                                                 if (features[3] <= 0.04679800011217594) {
#                                                     classes[0] = 6;
#                                                     classes[1] = 0;
#                                                 } else {
#                                                     classes[0] = 0;
#                                                     classes[1] = 3;
#                                                 }
#                                             }
#                                         } else {
#                                             classes[0] = 5;
#                                             classes[1] = 0;
#                                         }
#                                     } else {
#                                         if (features[8] <= 0.040671998634934425) {
#                                             if (features[14] <= 0.1855430006980896) {
#                                                 if (features[8] <= -0.05619649961590767) {
#                                                     if (features[18] <= -0.038949498906731606) {
#                                                         if (features[14] <= -0.058667498640716076) {
#                                                             classes[0] = 0;
#                                                             classes[1] = 2;
#                                                         } else {
#                                                             if (features[9] <= -0.008723499719053507) {
#                                                                 classes[0] = 11;
#                                                                 classes[1] = 0;
#                                                             } else {
#                                                                 classes[0] = 0;
#                                                                 classes[1] = 1;
#                                                             }
#                                                         }
#                                                     } else {
#                                                         classes[0] = 0;
#                                                         classes[1] = 7;
#                                                     }
#                                                 } else {
#                                                     if (features[19] <= -0.035220999270677567) {
#                                                         classes[0] = 0;
#                                                         classes[1] = 1;
#                                                     } else {
#                                                         if (features[0] <= 0.13395750150084496) {
#                                                             if (features[17] <= 0.20460250228643417) {
#                                                                 if (features[15] <= -0.04441650025546551) {
#                                                                     if (features[13] <= 0.01326650008559227) {
#                                                                         classes[0] = 5;
#                                                                         classes[1] = 0;
#                                                                     } else {
#                                                                         classes[0] = 0;
#                                                                         classes[1] = 2;
#                                                                     }
#                                                                 } else {
#                                                                     classes[0] = 39;
#                                                                     classes[1] = 0;
#                                                                 }
#                                                             } else {
#                                                                 if (features[6] <= -0.030434999614953995) {
#                                                                     classes[0] = 1;
#                                                                     classes[1] = 0;
#                                                                 } else {
#                                                                     classes[0] = 0;
#                                                                     classes[1] = 1;
#                                                                 }
#                                                             }
#                                                         } else {
#                                                             classes[0] = 0;
#                                                             classes[1] = 1;
#                                                         }
#                                                     }
#                                                 }
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 5;
#                                             }
#                                         } else {
#                                             if (features[18] <= -0.16951049864292145) {
#                                                 classes[0] = 5;
#                                                 classes[1] = 0;
#                                             } else {
#                                                 if (features[6] <= 0.02397850062698126) {
#                                                     if (features[11] <= -0.023068499751389027) {
#                                                         if (features[1] <= -0.06960200145840645) {
#                                                             classes[0] = 0;
#                                                             classes[1] = 1;
#                                                         } else {
#                                                             classes[0] = 3;
#                                                             classes[1] = 0;
#                                                         }
#                                                     } else {
#                                                         if (features[13] <= -0.05861849896609783) {
#                                                             classes[0] = 1;
#                                                             classes[1] = 0;
#                                                         } else {
#                                                             if (features[5] <= 0.31350550055503845) {
#                                                                 if (features[9] <= -0.05554899945855141) {
#                                                                     if (features[0] <= -0.001819500017518294) {
#                                                                         classes[0] = 0;
#                                                                         classes[1] = 5;
#                                                                     } else {
#                                                                         if (features[9] <= -0.14247150346636772) {
#                                                                             classes[0] = 0;
#                                                                             classes[1] = 1;
#                                                                         } else {
#                                                                             classes[0] = 2;
#                                                                             classes[1] = 0;
#                                                                         }
#                                                                     }
#                                                                 } else {
#                                                                     classes[0] = 0;
#                                                                     classes[1] = 29;
#                                                                 }
#                                                             } else {
#                                                                 classes[0] = 1;
#                                                                 classes[1] = 0;
#                                                             }
#                                                         }
#                                                     }
#                                                 } else {
#                                                     if (features[9] <= 0.008533500134944916) {
#                                                         if (features[19] <= 0.13239650055766106) {
#                                                             classes[0] = 0;
#                                                             classes[1] = 2;
#                                                         } else {
#                                                             classes[0] = 1;
#                                                             classes[1] = 0;
#                                                         }
#                                                     } else {
#                                                         classes[0] = 4;
#                                                         classes[1] = 0;
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 } else {
#                                     if (features[7] <= 0.17314449697732925) {
#                                         classes[0] = 0;
#                                         classes[1] = 24;
#                                     } else {
#                                         if (features[12] <= -0.058271000161767006) {
#                                             classes[0] = 0;
#                                             classes[1] = 3;
#                                         } else {
#                                             classes[0] = 4;
#                                             classes[1] = 0;
#                                         }
#                                     }
#                                 }
#                             }
#                         } else {
#                             if (features[10] <= -0.07387899979948997) {
#                                 classes[0] = 0;
#                                 classes[1] = 16;
#                             } else {
#                                 if (features[4] <= -0.0368610005825758) {
#                                     if (features[8] <= -0.15254200249910355) {
#                                         classes[0] = 0;
#                                         classes[1] = 7;
#                                     } else {
#                                         if (features[15] <= 0.02540699951350689) {
#                                             classes[0] = 0;
#                                             classes[1] = 3;
#                                         } else {
#                                             if (features[16] <= 0.11433400213718414) {
#                                                 classes[0] = 7;
#                                                 classes[1] = 0;
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 1;
#                                             }
#                                         }
#                                     }
#                                 } else {
#                                     if (features[0] <= -0.14999499917030334) {
#                                         classes[0] = 0;
#                                         classes[1] = 4;
#                                     } else {
#                                         if (features[9] <= -0.004345500026829541) {
#                                             if (features[3] <= 0.07891950011253357) {
#                                                 if (features[18] <= -0.33379100263118744) {
#                                                     classes[0] = 0;
#                                                     classes[1] = 1;
#                                                 } else {
#                                                     if (features[6] <= -0.30924899876117706) {
#                                                         classes[0] = 0;
#                                                         classes[1] = 1;
#                                                     } else {
#                                                         if (features[13] <= -0.05545100010931492) {
#                                                             if (features[1] <= -0.03350000083446503) {
#                                                                 classes[0] = 1;
#                                                                 classes[1] = 0;
#                                                             } else {
#                                                                 classes[0] = 0;
#                                                                 classes[1] = 1;
#                                                             }
#                                                         } else {
#                                                             if (features[12] <= -0.06593349948525429) {
#                                                                 if (features[16] <= 0.04406599886715412) {
#                                                                     classes[0] = 0;
#                                                                     classes[1] = 1;
#                                                                 } else {
#                                                                     classes[0] = 4;
#                                                                     classes[1] = 0;
#                                                                 }
#                                                             } else {
#                                                                 classes[0] = 59;
#                                                                 classes[1] = 0;
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 1;
#                                             }
#                                         } else {
#                                             if (features[6] <= -0.01543149957433343) {
#                                                 if (features[20] <= 0.02927249949425459) {
#                                                     if (features[19] <= 0.1306079998612404) {
#                                                         if (features[16] <= -0.042393000796437263) {
#                                                             classes[0] = 1;
#                                                             classes[1] = 0;
#                                                         } else {
#                                                             classes[0] = 0;
#                                                             classes[1] = 11;
#                                                         }
#                                                     } else {
#                                                         classes[0] = 1;
#                                                         classes[1] = 0;
#                                                     }
#                                                 } else {
#                                                     classes[0] = 4;
#                                                     classes[1] = 0;
#                                                 }
#                                             } else {
#                                                 if (features[19] <= 0.16540950536727905) {
#                                                     if (features[8] <= 0.16578499972820282) {
#                                                         if (features[19] <= -0.104823999106884) {
#                                                             if (features[1] <= -0.036924498388543725) {
#                                                                 classes[0] = 0;
#                                                                 classes[1] = 1;
#                                                             } else {
#                                                                 classes[0] = 1;
#                                                                 classes[1] = 0;
#                                                             }
#                                                         } else {
#                                                             if (features[10] <= 0.0032330001704394817) {
#                                                                 if (features[5] <= -0.06534199882298708) {
#                                                                     classes[0] = 0;
#                                                                     classes[1] = 1;
#                                                                 } else {
#                                                                     classes[0] = 3;
#                                                                     classes[1] = 0;
#                                                                 }
#                                                             } else {
#                                                                 classes[0] = 30;
#                                                                 classes[1] = 0;
#                                                             }
#                                                         }
#                                                     } else {
#                                                         if (features[6] <= 0.04456700012087822) {
#                                                             classes[0] = 0;
#                                                             classes[1] = 2;
#                                                         } else {
#                                                             classes[0] = 2;
#                                                             classes[1] = 0;
#                                                         }
#                                                     }
#                                                 } else {
#                                                     if (features[12] <= 0.04588400013744831) {
#                                                         classes[0] = 3;
#                                                         classes[1] = 0;
#                                                     } else {
#                                                         classes[0] = 0;
#                                                         classes[1] = 3;
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#                     }
#                 } else {
#                     if (features[15] <= 0.2206450030207634) {
#                         if (features[5] <= -0.5054620057344437) {
#                             if (features[20] <= -2.553045444190502) {
#                                 classes[0] = 0;
#                                 classes[1] = 1;
#                             } else {
#                                 classes[0] = 3;
#                                 classes[1] = 0;
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 31;
#                         }
#                     } else {
#                         classes[0] = 6;
#                         classes[1] = 0;
#                     }
#                 }
#             } else {
#                 if (features[6] <= 0.08215650171041489) {
#                     if (features[11] <= -0.8410555124282837) {
#                         classes[0] = 4;
#                         classes[1] = 0;
#                     } else {
#                         if (features[10] <= 0.2650754898786545) {
#                             if (features[11] <= 1.4892715513706207) {
#                                 if (features[20] <= -0.3634504973888397) {
#                                     if (features[9] <= 0.2013319954276085) {
#                                         classes[0] = 2;
#                                         classes[1] = 0;
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 4;
#                                     }
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 51;
#                                 }
#                             } else {
#                                 classes[0] = 1;
#                                 classes[1] = 0;
#                             }
#                         } else {
#                             if (features[16] <= 0.20532899349927902) {
#                                 classes[0] = 4;
#                                 classes[1] = 0;
#                             } else {
#                                 if (features[9] <= 0.6279589831829071) {
#                                     classes[0] = 0;
#                                     classes[1] = 4;
#                                 } else {
#                                     classes[0] = 1;
#                                     classes[1] = 0;
#                                 }
#                             }
#                         }
#                     }
#                 } else {
#                     if (features[8] <= -0.4661024957895279) {
#                         classes[0] = 0;
#                         classes[1] = 1;
#                     } else {
#                         classes[0] = 8;
#                         classes[1] = 0;
#                     }
#                 }
#             }
#         }
#
#         return findMax(classes);
#     }
#
#     public static void main(String[] args) {
#         if (args.length == 21) {
#
#             // Features:
#             double[] features = new double[args.length];
#             for (int i = 0, l = args.length; i < l; i++) {
#                 features[i] = Double.parseDouble(args[i]);
#             }
#
#             // Prediction:
#             int prediction = DecisionTreeClassifier.predict(features);
#             System.out.println(prediction);
#
#         }
#     }
# }
# C:\Users\Daniel\anaconda3\envs\gputest\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.neural_network.multilayer_perceptron module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neural_network. Anything that cannot be imported from sklearn.neural_network is now part of the private API.
#   warnings.warn(message, FutureWarning)
